# %% [markdown]
# <a href="https://colab.research.google.com/github/abhirampitla-13/2311cs020528/blob/main/dbscan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = "/content/Wholesale customers data.csv"
df = pd.read_csv(file_path)

# %%
df
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen
# 0          1338
# 1          1776
# 2          7844
# 3          1788
# 4          5185
# ..          ...
# ...

# %%
import pandas as pd
df = pd.read_csv("Wholesale customers data.csv")
df.head() # Removed the extra space before df.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
import pandas as pd
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt


db = DBSCAN(eps=0.5, min_samples=5)
y_predicted = db.fit_predict(df[['Fresh', 'Milk']])

df['cluster'] = y_predicted

df1 = df[df.cluster == 0]
df2 = df[df.cluster == 1]
df3 = df[df.cluster == 2]

plt.scatter(df1['Milk'], df1['Fresh'], color='green', label='Cluster 0')
plt.scatter(df2['Milk'], df2['Fresh'], color='red', label='Cluster 1')
plt.scatter(df3['Milk'], df3['Fresh'], color='black', label='Cluster 2')

if -1 in df['cluster'].values:
    noise = df[df.cluster == -1]
    plt.scatter(noise['Milk'], noise['Fresh'], color='yellow', label='Noise')

plt.xlabel('Milk')
plt.ylabel('Fresh')
plt.legend()
plt.title('DBSCAN Clustering')
plt.show()

# %%
dbscan = DBSCAN(eps=0.5, min_samples=5)
dbscan.fit(df.iloc[:, 1:])
# Out:
# DBSCAN()

# %%
cl=pd.DataFrame(dbscan.labels_,columns=['cluster'])

# %%
cl
# Out:
#      cluster
# 0         -1
# 1         -1
# 2         -1
# 3         -1
# 4         -1
# ..       ...
# 435       -1
# 436       -1
# 437       -1
# 438       -1
# 439       -1
#
# [440 rows x 1 columns]
