# %% [markdown]
# <a href="https://colab.research.google.com/github/abhirampitla-13/2311cs020528/blob/main/correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(42)
data = {
    "Study Hours": np.random.randint(1, 11, 50),
    "Marks": np.random.randint(40, 101, 50),
    "Screen Time": np.random.randint(1, 11, 50),  # Changed: low=1, high=11
    "Traveling": np.random.randint(0, 2, 50),
    "Sleep Hours": np.random.randint(3, 7, 50),  # Changed: low=3, high=7
}
df = pd.DataFrame(data)
corr = df.corr()
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()
